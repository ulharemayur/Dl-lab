# %%
from keras.applications.vgg16 import VGG16
model = VGG16()
# Out:
# ...
#  10379264/553467096 [..............................] - ETA: 3:55

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
import random
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image_folder = "C:\\Users\\kulka\\Downloads\\archive\\datasets\\train\\images"

# %%
image_files = [os.path.join(image_folder,f) for f in os.listdir(image_folder) if f.lower().endswith(('.jpg','.jpeg','.png','.gif','.bmp'))]

# %%
image_data = []
for image_path in image_files:
    image = load_img(image_path,target_size=(224,224))
    image = img_to_array(image)
    image = image.reshape((1,image.shape[0],image.shape[1],image.shape[2]))
    image = preprocess_input(image)
    image_data.append(image)

# %%
random_index = random.randint(0, len(image_data) - 1)
random_image = image_data[random_index]

# %%
yhat = model.predict(random_image)
# Out:
# 1/1 [==============================] - 0s 306ms/step

# %%
label = decode_predictions(yhat)

# %%
label = label[0][0]

# %%
plt.title(label[1])
img = mpimg.imread(image_files[random_index])
plt.imshow(img)
plt.show()

# %%
print("Predicted Label: ",label[1].capitalize())
# Out:
# Predicted Label:  Hamster
